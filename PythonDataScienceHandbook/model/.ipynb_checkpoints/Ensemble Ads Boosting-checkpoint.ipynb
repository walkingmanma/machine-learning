# %% [markdown]
# ## Ada Boosting algorithm
# ###### 1.For each successive iteration, the sample weights are individually modified and the learning algorithm is reapplied to the reweighted data.
# ###### 2. At a given step, those training examples that were incorrectly predicted by the boosted model induced at the previous step have their weights increased, whereas the weights are decreased for those that were predicted correctly.
# ###### 3.Each subsequent weak learner is thereby forced to concentrate on the examples that are missed by the previous ones in the sequence

# %% [markdown]
# 1. For multi-class classification, AdaBoostClassifier implements AdaBoost-SAMME and AdaBoost-SAMME.R [ZZRH2009].
# 2. For regression, AdaBoostRegressor implements AdaBoost.R2 [D1997].
#
# 3. The number of weak learners is controlled by the parameter n_estimators.
# 4. The learning_rate parameter controls the contribution of the weak learners in the final combination.
# 5. By default, weak learners are decision stumps. Different weak learners can be specified through the base_estimator parameter.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier

# %%
iris = load_iris()
clf = AdaBoostClassifier(n_estimators=100)
clf.fit(iris.data,iris.target)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=100, random_state=None)

# %% [markdown]
# ## Two-class AdaBoost¶

# %%
print(__doc__)
# %matplotlib inline
# Out:
# Automatically created module for IPython interactive environment

# %%
# common libarary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import dataset libs and algorithm libs
from sklearn.datasets import make_gaussian_quantiles
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
# Construct dataset
X1, y1 = make_gaussian_quantiles(cov=2.,
                                 n_samples=200, n_features=2,
                                 n_classes=2, random_state=1)
X2, y2 = make_gaussian_quantiles(mean=(3, 3), cov=1.5,
                                 n_samples=300, n_features=2,
                                 n_classes=2, random_state=1)
X = np.concatenate((X1, X2))
y = np.concatenate((y1, - y2 + 1))

# %%
# Create and fit an AdaBoosted decision tree
# The max_depth = 1 of the Decision trees is a weak learner ,the accuracy is less 50per.
bdt = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1),
                         algorithm="SAMME",
                         n_estimators=200)

bdt.fit(X, y)
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=200, random_state=None)

# %%
# Plot the decision boundaries
plot_colors = "br"
plot_step = 0.02
class_names = "AB"

plt.figure(figsize=(10, 5))
plt.subplot(121)

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                     np.arange(y_min, y_max, plot_step))


# xx.ravel() 是指将多维数组flatted平铺生成一个一维数组
# np.c_   是指将一个数组按照某一坐标轴split ， 然后按照另一坐标轴组合
Z = bdt.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

#####------------------------------------------------------------
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)  
plt.axis("tight")

#----------------------------------------------------------------

# Plot the training points
# 请注意如下idx = np.where(y ==i), y是一个矩阵
# zip()  合成tuple

for i, n, c in zip(range(2), class_names, plot_colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1],
                c=c, cmap=plt.cm.Paired,
                s=20, edgecolor='k',
                label="Class %s" % n)
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.legend(loc='upper right')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Decision Boundary')



# Plot the two-class decision scores
# bdt.decision_function(X)   计算 decision_function(X)的决策函数的值，OK. 决策函数是指最终最优化之后得到的Ht
# Ht = 1/2ln exp(预测成功的概率 )/exp(预测失败的概率)
# 换做该例中分别表示classA 和 classB
twoclass_output = bdt.decision_function(X)
plot_range = (twoclass_output.min(), twoclass_output.max())
plt.subplot(122)
for i, n, c in zip(range(2), class_names, plot_colors):
    plt.hist(twoclass_output[y == i],
             bins=10,
             range=plot_range,
             facecolor=c,
             label='Class %s' % n,
             alpha=.5,
             edgecolor='k')
x1, x2, y1, y2 = plt.axis()
plt.axis((x1, x2, y1, y2 * 1.2))
plt.legend(loc='upper right')
plt.ylabel('Samples')
plt.xlabel('Score')
plt.title('Decision Scores')

plt.tight_layout()
plt.subplots_adjust(wspace=0.35)
plt.show()

# %%
twoclass_output[twoclass_output[:] < 0].shape
# Out:
# (247,)
